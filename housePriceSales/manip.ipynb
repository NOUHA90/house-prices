# %% [markdown]
# # **House Prices - Advanced Regression Techniques**

# %%
from IPython.display import Image
Image('housesbanner.png')

# %%
# Import library
import pandas  as pd #Data manipulation
import numpy as np #Data manipulationfrom data import Data
import matplotlib.pyplot as plt # Visualization
import seaborn as sns #Visualization
from data import Data
from explorer import ExploreRelationshipsVariables as erv

# %matplotlib inline

# sns.set_style("whitegrid")
# plt.style.use("fivethirtyeight")

# %%
dataframe = Data()
explor = erv()

# %%
house_prices_data = dataframe.read_original_data('house_prices_cleaned_train_data.csv')

# %%
house_prices_data = house_prices_data.drop(columns=['Unnamed: 0'])

# %% [markdown]
# ## ** ANALYZE the Relationships Between Variables **

# %%
#explor.crosstab_relationship_target_and_categorical_columns(house_prices_data, 'SalePrice')

# %%
#explor.barplot_relationship_target_and_categorical_columns(house_prices_data, 'SalePrice')

# %%
explor.clustermap_relationship(house_prices_data)

# %%
explor.heatmap_correlation_relationship(house_prices_data)

# %%
explor.heatmap_corr_target_features('SalePrice', house_prices_data)

# %%
#house_prices_data.keys()

# %%
sns.pairplot(house_prices_data[['OverallQual', 'GrLivArea', 'GarageArea', 'TotalBsmtSF','1stFlrSF', 'FullBath', 'TotRmsAbvGrd', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'Fireplaces', 'GarageYrBlt', 'SalePrice']])

# %%
explor.jointplot_relationship_regression('GrLivArea','SalePrice', house_prices_data)

# %%
explor.residplot_regression('GrLivArea','SalePrice', house_prices_data)
