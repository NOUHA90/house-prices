# %%
# Import library
import pandas  as pd #Data manipulation
import numpy as np #Data manipulation
import matplotlib.pyplot as plt # Visualization
import seaborn as sns #Visualization
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LinearRegression
from sklearn import set_config
set_config(display='diagram')
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
house_prices_train = pd.read_csv('house_prices_cleaned_train_data.csv')
house_prices_test = pd.read_csv('house_prices_cleaned_test_data.csv')
train_ID = house_prices_train.Id
test_ID = house_prices_test.Id
target = pd.read_csv('target.csv')
house_prices_train.shape, house_prices_test.shape, target.shape
# Out:
# ((1460, 78), (1459, 77), (1460, 2))

# %%
house_prices_train = house_prices_train.drop(columns=['Unnamed: 0'])

# %%
house_prices_test = house_prices_test.drop(columns=['Unnamed: 0'])

# %%
target = target.drop(columns=['Unnamed: 0'])

# %%
house_prices_train.shape, house_prices_test.shape, target.shape
# Out:
# ((1460, 77), (1459, 76), (1460, 1))

# %%
house_prices_train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0   1          60       RL         65.0     8450   Pave      Reg         Lvl
# 1   2          20       RL         80.0     9600   Pave      Reg         Lvl
# 2   3          60       RL         68.0    11250   Pave      IR1         Lvl
# 3   4          70       RL         60.0     9550   Pave      IR1         Lvl
# 4   5          60       RL         84.0    14260   Pave      IR1         Lvl
#
#   Utilities LotConfig  ... EnclosedPorch 3SsnPorch ScreenPorch PoolArea  \
# 0    AllPub    Inside  ...             0         0           0        0
# 1    AllPub       FR2  ...             0         0           0        0
# 2    AllPub    Inside  ...             0         0           0        0
# 3    AllPub    Corner  ...           272         0           0        0
# 4    AllPub       FR2  ...             0         0           0        0
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
house_prices_test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0  1461          20       RH         80.0    11622   Pave      Reg
# 1  1462          20       RL         81.0    14267   Pave      IR1
# 2  1463          60       RL         74.0    13830   Pave      IR1
# 3  1464          60       RL         78.0     9978   Pave      IR1
# 4  1465         120       RL         43.0     5005   Pave      IR1
#
#   LandContour Utilities LotConfig  ... OpenPorchSF EnclosedPorch 3SsnPorch  \
# 0         Lvl    AllPub    Inside  ...           0             0         0
# 1         Lvl    AllPub    Corner  ...          36             0         0
# 2         Lvl    AllPub    Inside  ...          34             0         0
# 3         Lvl    AllPub    Inside  ...          36             0         0
# 4         HLS    AllPub    Inside  ...          82             0         0
#
#   ScreenPorch PoolArea MiscVal  MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
numeric_features = ['OverallQual', 'GrLivArea', 'GarageArea', 'TotalBsmtSF']
numeric_transformer = Pipeline([('impute', SimpleImputer(strategy='mean'))])
numeric_transformer
# Out:
# Pipeline(steps=[('impute', SimpleImputer())])

# %%
preprocess_pipeline = ColumnTransformer([('numeric_features', numeric_transformer, numeric_features)])
preprocess_pipeline
# Out:
# ColumnTransformer(transformers=[('numeric_features',
#                                  Pipeline(steps=[('impute', SimpleImputer())]),
#                                  ['OverallQual', 'GrLivArea', 'GarageArea',
#                                   'TotalBsmtSF'])])

# %%
test = preprocess_pipeline.fit_transform(house_prices_test)

# %%
test = pd.DataFrame(test, columns = ['OverallQual', 'GrLivArea', 'GarageArea', 'TotalBsmtSF'])
test
# Out:
#       OverallQual  GrLivArea  GarageArea  TotalBsmtSF
# 0             5.0      896.0       730.0        882.0
# 1             6.0     1329.0       312.0       1329.0
# 2             5.0     1629.0       482.0        928.0
# 3             6.0     1604.0       470.0        926.0
# 4             8.0     1280.0       506.0       1280.0
# ...           ...        ...         ...          ...
# 1454          4.0     1092.0         0.0        546.0
# 1455          4.0     1092.0       286.0        546.0
# 1456          5.0     1224.0       576.0       1224.0
# 1457          5.0      970.0         0.0        912.0
# 1458          7.0     2000.0       650.0        996.0
#
# [1459 rows x 4 columns]

# %%
linreg = LinearRegression()
linreg.fit(house_prices_train[['OverallQual', 'GrLivArea', 'GarageArea', 'TotalBsmtSF']], target)
# Out:
# LinearRegression()

# %%
 # model evaluation for testing set
y_train_predict = linreg.predict(house_prices_train[['OverallQual', 'GrLivArea', 'GarageArea', 'TotalBsmtSF']])
print(y_train_predict)
# Out:
# [[210575.0291171 ]
#  [172284.80309762]
#  [219465.60009816]
#  ...
#  [230997.04138127]
#  [120577.16153784]
#  [136158.26789912]]

# %%
 # model evaluation for testing set
y_test_predict = linreg.predict(test)
print(y_test_predict)
# Out:
# [[134908.76340022]
#  [168739.89689374]
#  [155294.6225375 ]
#  ...
#  [151207.99113493]
#  [ 96669.28854275]
#  [233965.87854725]]

# %%
y_test_predict.shape
# Out:
# (1459, 1)

# %%
test_ID = pd.DataFrame(test_ID)
test_ID
# Out:
#         Id
# 0     1461
# 1     1462
# 2     1463
# 3     1464
# 4     1465
# ...    ...
# 1454  2915
# 1455  2916
# 1456  2917
# 1457  2918
# 1458  2919
#
# [1459 rows x 1 columns]

# %%
y_test_predict = pd.DataFrame(y_test_predict, columns = ["SalePrice"])

# %%
y_test_predict
# Out:
#           SalePrice
# 0     134908.763400
# 1     168739.896894
# 2     155294.622538
# 3     178349.434305
# 4     226237.125480
# ...             ...
# 1454   66254.860481
# 1455   82913.270730
# 1456  151207.991135
# 1457   96669.288543
# 1458  233965.878547
#
# [1459 rows x 1 columns]

# %%
sample_submission = test_ID.join(y_test_predict)

# %%
sample_submission.head()
# Out:
#      Id      SalePrice
# 0  1461  134908.763400
# 1  1462  168739.896894
# 2  1463  155294.622538
# 3  1464  178349.434305
# 4  1465  226237.125480

# %%
sample_submission.to_csv('nouha_sample_submission.csv',index =False)
